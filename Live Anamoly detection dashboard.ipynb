# %%
pip install streamlit
# Out:
# Requirement already satisfied: streamlit in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (1.41.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: packaging<25,>=20 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (5.29.1)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from streamlit) (6.4.2)
# Requirement already satisfied: jinja2 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from altair<6,>=4.0->streamlit) (1.18.4)
# Requirement already satisfied: colorama in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from requests<3,>=2.27->streamlit) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.2.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import IsolationForest
import streamlit as st
import time 
import matplotlib.pyplot as plt

# %%
def load_data():
    cashback_claims = pd.read_csv('cashback_claims.csv')
    processed_analysis = pd.read_csv('processed_cashback_analysis.csv')
    return cashback_claims,processed_analysis

cashback_claims,processed_analysis = load_data()

# %%
print(cashback_claims,processed_analysis)
# Out:
#    User ID  Cashback Amount  Claim Date  Number of Claims  \
# 0       U1        33.731404  2023-01-01                 3
# 1       U2        41.747040  2023-01-02                 3
# 2       U3        60.856437  2023-01-03                 1
# 3       U4        42.599363  2023-01-04                 3
# 4       U5        74.327885  2023-01-05                 4
# ..     ...              ...         ...               ...
# 95     U96        48.713566  2023-04-06                 1
# 96     U97        37.699267  2023-04-07                 4
# 97     U98        54.686877  2023-04-08                 4
# 98     U99        26.260181  2023-04-09                 1
# 99    U100        77.808967  2023-04-10                 3
#
#     Total Cashback Claimed
# 0               326.706291
# 1               224.553225
# 2               325.434074
# 3               143.518860
# 4               234.559158
# ..                     ...
# 95              120.634194
# 96              359.201820
# 97              338.926295
# 98              292.776143
# 99              189.783175
#
# [100 rows x 5 columns]    User ID  Number of Claims  Total Cashback Claimed  anomaly_score  \
# 0       U1                 1               33.731404              1
# 1      U10                 1               98.400650             -1
# 2     U100                 1               77.808967              1
# 3      U11                 1               14.073623              1
# 4      U12                 1               84.641894              1
# ..     ...               ...                     ...            ...
# 95     U95                 1               86.878360              1
# 96     U96                 1               48.713566              1
# 97     U97                 1               37.699267              1
# 98     U98                 1               54.686877              1
# 99     U99                 1               26.260181              1
#
#     is_anomaly  potential_fraud
# 0        False            False
# 1         True            False
# 2        False            False
# 3        False            False
# 4        False            False
# ..         ...              ...
# 95       False            False
# 96       False            False
# 97       False            False
# 98       False            False
# 99       False            False
#
# [100 rows x 6 columns]

# %%
def preprocess_data(claims, analysis):
    data=pd.concat([claims, analysis],axis=0, ignore_index=True)
    return data
data = preprocess_data(cashback_claims, processed_analysis)
data
# Out:
#     User ID  Cashback Amount  Claim Date  Number of Claims  \
# 0        U1        33.731404  2023-01-01                 3
# 1        U2        41.747040  2023-01-02                 3
# 2        U3        60.856437  2023-01-03                 1
# 3        U4        42.599363  2023-01-04                 3
# 4        U5        74.327885  2023-01-05                 4
# ..      ...              ...         ...               ...
# 195     U95              NaN         NaN                 1
# 196     U96              NaN         NaN                 1
# 197     U97              NaN         NaN                 1
# 198     U98              NaN         NaN                 1
# 199     U99              NaN         NaN                 1
#
#      Total Cashback Claimed  anomaly_score is_anomaly potential_fraud
# 0                326.706291            NaN        NaN             NaN
# 1                224.553225            NaN        NaN             NaN
# 2                325.434074            NaN        NaN             NaN
# 3                143.518860            NaN        NaN             NaN
# 4                234.559158            NaN        NaN             NaN
# ..                      ...            ...        ...             ...
# 195               86.878360            1.0      False           False
# 196               48.713566            1.0      False           False
# 197               37.699267            1.0      False           False
# 198               54.686877            1.0      False           False
# 199               26.260181            1.0      False           False
#
# [200 rows x 8 columns]

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2024.2)
# Requirement already satisfied: six>=1.5 in c:\users\archana sundar\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
def anomaly_detection(data):
    model = IsolationForest(contamination=0.05, random_state=42)
    numeric_features = data.select_dtypes(include=['float64', 'int64']).drop(columns=['User ID'], errors='ignore')
    data['anomaly_score'] = model.fit_predict(numeric_features)
    data['status'] = data['anomaly_score'].apply(lambda x: 'Normal' if x == 1 else 'Fraud')
    return data

anomaly_detection(data)
# Out:
#     User ID  Cashback Amount  Claim Date  Number of Claims  \
# 0        U1        33.731404  2023-01-01                 3
# 1        U2        41.747040  2023-01-02                 3
# 2        U3        60.856437  2023-01-03                 1
# 3        U4        42.599363  2023-01-04                 3
# 4        U5        74.327885  2023-01-05                 4
# ..      ...              ...         ...               ...
# 195     U95              NaN         NaN                 1
# 196     U96              NaN         NaN                 1
# 197     U97              NaN         NaN                 1
# 198     U98              NaN         NaN                 1
# 199     U99              NaN         NaN                 1
#
#      Total Cashback Claimed  anomaly_score is_anomaly potential_fraud  status
# 0                326.706291              1        NaN             NaN  Normal
# 1                224.553225              1        NaN             NaN  Normal
# 2                325.434074              1        NaN             NaN  Normal
# 3                143.518860              1        NaN             NaN  Normal
# 4                234.559158              1        NaN             NaN  Normal
# ..                      ...            ...        ...             ...     ...
# 195               86.878360              1      False           False  Normal
# 196               48.713566              1      False           False  Normal
# 197               37.699267              1      False           False  Normal
# 198               54.686877              1      False           False  Normal
# 199               26.260181              1      False           False  Normal
#
# [200 rows x 9 columns]

# %%
# %%writefile visual.py

import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

def plot_visualizations(data):  # Accept 'data' as a parameter
    st.title("Cashback Claims Analysis Dashboard")

    # Status Count Bar Chart
    st.subheader("Bar Chart: Normal vs Fraudulent Claims")
    status_counts = data['status'].value_counts()
    fig, ax = plt.subplots()
    sns.barplot(x=status_counts.index, y=status_counts.values, palette='coolwarm', ax=ax)
    ax.set_title("Number of Normal vs Fraudulent Claims")
    ax.set_xlabel("Status")
    ax.set_ylabel("Count")
    st.pyplot(fig)

    # Pie Chart of Status
    st.subheader("Pie Chart: Proportion of Fraudulent and Normal Claims")
    fig2, ax2 = plt.subplots()
    ax2.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', colors=['#4CAF50', '#FF5733'])
    ax2.set_title("Proportion of Normal vs Fraudulent Claims")
    st.pyplot(fig2)

    # Scatter Plot for Anomaly Detection
    st.subheader("Scatter Plot: Anomaly Detection")
    fig3, ax3 = plt.subplots()
    numeric_features = data.select_dtypes(include=['float64', 'int64'])
    if len(numeric_features.columns) > 1:
        scatter_x = numeric_features.columns[0]
        scatter_y = numeric_features.columns[1]
        sns.scatterplot(x=numeric_features[scatter_x], y=numeric_features[scatter_y], hue=data['status'], palette='coolwarm', ax=ax3)
        ax3.set_title("Scatter Plot of Anomaly Detection")
        ax3.set_xlabel(scatter_x)
        ax3.set_ylabel(scatter_y)
        st.pyplot(fig3)
    else:
        st.warning("Not enough numeric features for a scatter plot.")

# Main Execution
if __name__ == "__main__":
    
    
    def load_data():
        data = pd.DataFrame({
            'status': ['Normal', 'Fraud', 'Normal', 'Fraud', 'Normal'],
            'feature1': [1, 5, 3, 8, 2],
            'feature2': [10, 20, 15, 25, 12]
        })
        return data

    data = load_data()  # Load your data
    plot_visualizations(data)  # Pass 'data' explicitly to the function
    st.subheader("Processed Data Preview")
    st.dataframe(data)
# Out:
# Writing visual.py
